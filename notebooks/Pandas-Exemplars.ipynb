# %%
import numpy as np
from matplotlib import pyplot as plt
# Set up the figure
plt.figure(figsize=(8, 6))

# Original supply and demand curves
prices = np.linspace(2, 8, 100)  # Price levels
original_demand = 10 - 0.5 * prices  # Downward-sloping demand curve
original_supply = 0.5 * prices - 1  # Upward-sloping supply curve

# New supply and demand curves after changes
new_demand = 10 - 0.5 * prices  # Demand remains the same
new_supply = 0.5 * prices - 3  # Shift in supply curve (leftward due to reduced supply)

# Plot original curves
plt.plot(original_demand, prices, label="Original Demand", linestyle="--", color="blue")
plt.plot(original_supply, prices, label="Original Supply", linestyle="--", color="green")

# Plot new curves
plt.plot(new_demand, prices, label="New Demand", color="blue")
plt.plot(new_supply, prices, label="New Supply", color="green")

# Highlight equilibrium points
plt.scatter(6, 4, color="black", label="Original Equilibrium", zorder=5)  # Original equilibrium
plt.scatter(4, 5, color="red", label="New Equilibrium", zorder=5)  # New equilibrium

# Add labels and legend
plt.title("Supply-Demand Dynamics for Arabica Beans", fontsize=14)
plt.xlabel("Quantity", fontsize=12)
plt.ylabel("Price", fontsize=12)
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()

# Show the graph
plt.show()

# %%
# Data for supply curve
quantity_supplied = np.linspace(0, 10, 100)  # Quantities supplied
marginal_cost = 2 + 0.5 * quantity_supplied**2  # Rising marginal cost

# Plot the supply curve
plt.figure(figsize=(8, 6))
plt.plot(quantity_supplied, marginal_cost, label="Supply Curve (Upward Sloping)", color="green")

# Add labels, title, and legend
plt.title("Upward-Sloping Supply Curve", fontsize=14)
plt.xlabel("Quantity Supplied", fontsize=12)
plt.ylabel("Price (Marginal Cost)", fontsize=12)
plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()

# Show the graph
plt.show()

# %% [markdown]
# ## Supply-Demand Curve at Normal Equilibrium

# %%
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Supply Curve', linestyle='-', linewidth=2)

# Equilibrium point
equilibrium_price = 50
equilibrium_quantity = 50
plt.scatter(equilibrium_quantity, equilibrium_price, color='red', label='Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(equilibrium_quantity + 2, equilibrium_price - 5, f'P = {equilibrium_price}', color='black')
plt.text(equilibrium_quantity - 15, equilibrium_price + 2, f'Q = {equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Supply-Demand Curve - Supply Shifting Left (&larr;)

# %%
# Plot the curves with equilibrium annotations
new_supply_price = price + 30
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(supply, new_supply_price, label='New Supply Curve (Shift Left) ', linestyle='--', linewidth=2, color="yellow")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 65
new_equilibrium_quantity = 35
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Supply Curve shift Left (<--)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Supply-Demand Curve - Supply Shifting Right (&rarr;)

# %%
# Plot the curves with equilibrium annotations
new_supply_price = price - 30
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(supply, new_supply_price, label='New Supply Curve (Shift Right) ', linestyle='--', linewidth=2, color="yellow")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 35
new_equilibrium_quantity = 65
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Supply Curve shift Right (-->)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Supply-Demand Curve - Demand shifting Left (&larr;)

# %%
# Define the data
price = np.linspace(0, 100, 100)
demand = 100 - price  # Original demand curve
new_demand = 70 - price  # Shifted demand curve
supply = price  # Supply curve
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(new_demand, price, label='New Demand Curve (Shift Left) ', linestyle='--', linewidth=2, color="yellow")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 35
new_equilibrium_quantity = 35
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Demand Curve shift Left (<--)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Supply-Demand Curve - Demand shifting Right (&rarr;)

# %%
# Define the data
price = np.linspace(0, 100, 100)
demand = 100 - price  # Original demand curve
new_demand = 130 - price  # Shifted demand curve
supply = price  # Supply curve
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(new_demand, price, label='New Demand Curve (Shift Right) ', linestyle='--', linewidth=2, color="yellow")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 65
new_equilibrium_quantity = 65
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Demand Curve shift Right (-->)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Suppy-Demand Curve - Supply and Demand both shifting Right (&rarr;)

# %%
# Define the data
price = np.linspace(0, 100, 100)
demand = 100 - price  # Original demand curve
new_demand = 130 - price  # Shifted demand curve
supply = price  # Supply curve
new_supply = price + 20 # Shifted supply curve
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(new_demand, price, label='New Demand Curve (Shift Right) ', linestyle='--', linewidth=2, color="yellow")
plt.plot(new_supply, price, label='New Supply Curve (Shift Right)', linestyle='--', linewidth=2, color="purple")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 55
new_equilibrium_quantity = 75
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Supply & Demand Curve shift Right (-->)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Suppy-Demand Curve - Supply and Demand both shifting Left (&larr;)

# %%
# Define the data
price = np.linspace(0, 100, 100)
demand = 100 - price  # Original demand curve
new_demand = 80 - price  # Shifted demand curve
supply = price  # Supply curve
new_supply = price - 30 # Shifted supply curve
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(new_demand, price, label='New Demand Curve (Shift Right) ', linestyle='--', linewidth=2, color="yellow")
plt.plot(new_supply, price, label='New Supply Curve (Shift Right)', linestyle='--', linewidth=2, color="purple")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 55
new_equilibrium_quantity = 25
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Supply & Demand Curve shift Left (<--)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Suppy-Demand Curve - Supply shifting right(&rarr;) and Demand both shifting Left (&larr;)

# %%
# Define the data
price = np.linspace(0, 100, 100)
demand = 100 - price  # Original demand curve
new_demand = 80 - price  # Shifted demand curve
supply = price  # Supply curve
new_supply = price + 30 # Shifted supply curve
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(new_demand, price, label='New Demand Curve (Shift Right) ', linestyle='--', linewidth=2, color="yellow")
plt.plot(new_supply, price, label='New Supply Curve (Shift Right)', linestyle='--', linewidth=2, color="purple")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 25
new_equilibrium_quantity = 55
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Supply Curve shift right (-->) & Demand Curve shift Left (<--)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()

# %% [markdown]
# ## Suppy-Demand Curve - Supply shifting left(&larr;) and Demand both shifting right (&rarr;)

# %%
# Define the data
price = np.linspace(0, 100, 100)
demand = 100 - price  # Original demand curve
new_demand = 120 - price  # Shifted demand curve
supply = price  # Supply curve
new_supply = price - 30 # Shifted supply curve
# Plot the curves with equilibrium annotations
plt.figure(figsize=(8, 6))
plt.plot(demand, price, label='Original Demand Curve', linestyle='-', linewidth=2)
plt.plot(supply, price, label='Original Supply Curve', linestyle='-', linewidth=2)
plt.plot(new_demand, price, label='New Demand Curve (Shift Right) ', linestyle='--', linewidth=2, color="yellow")
plt.plot(new_supply, price, label='New Supply Curve (Shift Right)', linestyle='--', linewidth=2, color="purple")

# Equilibrium point
orig_equilibrium_price = 50
orig_equilibrium_quantity = 50
new_equilibrium_price = 75
new_equilibrium_quantity = 45
plt.scatter(orig_equilibrium_quantity, orig_equilibrium_price, color='red', label='Orig-Equilibrium', zorder=5)
plt.scatter(new_equilibrium_quantity, new_equilibrium_price, color='black', label='New-Equilibrium', zorder=5)

# Add lines to specify equilibrium values
plt.axhline(y=orig_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=orig_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)
plt.axhline(y=new_equilibrium_price, color='gray', linestyle=':', linewidth=1)
plt.axvline(x=new_equilibrium_quantity, color='gray', linestyle=':', linewidth=1)

# Add text annotations for equilibrium values
plt.text(orig_equilibrium_quantity + 2, orig_equilibrium_price - 5, f'P1 = {orig_equilibrium_price}', color='black')
plt.text(orig_equilibrium_quantity - 15, orig_equilibrium_price + 2, f'Q1 = {orig_equilibrium_quantity}', color='black')
plt.text(new_equilibrium_quantity + 2, new_equilibrium_price - 5, f'P2 = {new_equilibrium_price}', color='black')
plt.text(new_equilibrium_quantity - 15, new_equilibrium_price + 2, f'Q2 = {new_equilibrium_quantity}', color='black')

# Add labels and annotations
plt.title('Supply and Demand Curve  - Supply Curve shift left (<--) & Demand Curve shift right (-->)', fontsize=14)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='-')
plt.axvline(0, color='black', linewidth=0.5, linestyle='-')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Display the plot
plt.show()
