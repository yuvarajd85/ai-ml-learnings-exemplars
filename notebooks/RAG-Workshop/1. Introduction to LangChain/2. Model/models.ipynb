# %% [markdown]
# # **Models**
# **(LLM and ChatModel)**
#
# - A model can be a **LLM** or a **ChatModel**.
# - LLMs handle various language operations such as translation, summarization, question answering, and content creation. **[Click Here](https://python.langchain.com/docs/integrations/llms/)** to check the complete list of LLMs which can be used with LangChain.
# - Chat Models are customized for conversational usage. **[Click Here](https://python.langchain.com/docs/integrations/chat/)** to check the complete list of LLMs which can be used with LangChain.
# - The output of a ChatModel (and therefore, of this chain) is a message.
#
# | Module | LLM | Chat Model |
# | :---: | :---: | :---: |
# | langchain_openai | OpenAI(api_key=key, model=`gpt-3.5-turbo-instruct`) | ChatOpenAI(api_key=key, model=`gpt-3.5-turbo`) |
# | langchain_google_genai | GoogleGenerativeAI(api_key=key, model=`gemini-1.5-pro-latest`) | ChatGoogleGenerativeAI(api_key=key, model=`gemini-1.5-pro-latest`) |
# | langchain_cohere | Cohere(api_key=key, model=`command`) | ChatCohere(api_key=key, model=`command`) |
# | langchain_anthropic | Anthropic(api_key=key, model=`claude-2.1`) | ChatAnthropic(api_key=key, model=`claude-3-opus-20240229`) |

# %% [markdown]
# ## **OpenAI - LLM and Chat Model**

# %%
# ! pip install langchain-openai

# %%
# Setup API Key

f = open('keys/.openai_api_key.txt')

OPENAI_API_KEY = f.read()

# %%
# Import OpenAI LLM Model
from langchain_openai.llms import OpenAI

# Set the OpenAI Key and initialize a LLM model
llm = OpenAI(api_key=OPENAI_API_KEY, model="gpt-4o-mini", temperature=1)

# Create a prompt
prompt = "How many states are there in India?"

# Pass the prompt to llm
print(llm.invoke(prompt))
# Out:
# **: 28 states and 8 Union territories.
#
# 38. **What is the national flower of India?**: Lotus.
#
# 39. **Who is the father of the Indian Constitution?**: Dr. B.R. Ambedkar.
#
# 40. **What is the currency of India?**: Indian Rupee (INR).
#
# 41. **Which river is known as the "Ganges of the South"?**: Godavari.
#
# 42. **What is the capital of the state of Kerala?**: Thiruvananthapuram.
#
# 43. **Who was the first person to climb Mount Everest?**: Sir Edmund Hillary and Tenzing Norgay.
#
# 44. **What does the word 'Bharat' mean?**: India.
#
# 45. **Which Indian city is known as the "Silicon Valley of India"?**: Bangalore.
#
# 46. **What is the national animal of India?**: Bengal Tiger.
#
# 47. **Which festival is known as the "Festival of Lights"?**: Diwali.
#
# 48. **Which is the largest lake in India?**: Vembanad Lake.
#
# 49. **What is the national vegetable of India?**: Pumpkin.
#
# 50. **What does 'Gandh

# %%
# Import OpenAI LLM Model
from langchain_openai import ChatOpenAI

# Set the OpenAI Key and initialize a LLM model
llm = ChatOpenAI(api_key=OPENAI_API_KEY, model="gpt-4o-mini", temperature=1)

# Create a prompt
prompt = "How many states are there in India?"

# Pass the prompt to llm
print(llm.invoke(prompt))
# Out:
# content='As of now, India has 28 states and 8 Union Territories.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 15, 'total_tokens': 30, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_6a5cd723c4', 'finish_reason': 'stop', 'logprobs': None} id='run--41bdd43b-8cb1-44fc-97d0-dec32c63b4df-0' usage_metadata={'input_tokens': 15, 'output_tokens': 15, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Import OpenAI ChatModel
from langchain_openai import ChatOpenAI

# Set the OpenAI Key and initialize a ChatModel
chat_model = ChatOpenAI(api_key=OPENAI_API_KEY, model="gpt-3.5-turbo", temperature=1)

prompt = "Tell me a short joke about Data Science"

print(chat_model.invoke(prompt))
# Out:
# content="Why did the data scientist break up with their computer? \n\nBecause it wasn't providing them with enough support vector machines!" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 15, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run--560ebb85-2e25-4d6a-b60c-e31ec43871f8-0' usage_metadata={'input_tokens': 15, 'output_tokens': 24, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# ChatModel
from langchain_openai import ChatOpenAI

model = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model="gpt-3.5-turbo", temperature=1)

prompt = "What is Machine Learning?"

chain = model

chain.invoke(prompt)

# Observe that the output is a AI Message

# %% [markdown]
# ## **Google GenAI - LLM and Chat Model**

# %%
# ! pip install langchain-google-genai

# %%
# Setup API Key

f = open('keys/.gemini.txt')

GOOGLE_API_KEY = f.read()

# %%
# Import Google LLM Model

from langchain_google_genai import GoogleGenerativeAI, ChatGoogleGenerativeAI

# Set the OpenAI Key and initialize a LLM model
llm = GoogleGenerativeAI(google_api_key=GOOGLE_API_KEY, model="gemini-2.5-flash", temperature=1)

# Create a prompt
prompt = "How many states are there in India?"

# Pass the prompt to llm
print(llm.invoke(prompt))
# Out:
# There are **28 states** in India.

# %%
# Import Google LLM Model

from langchain_google_genai import GoogleGenerativeAI, ChatGoogleGenerativeAI

# Set the OpenAI Key and initialize a LLM model
llm = ChatGoogleGenerativeAI(google_api_key=GOOGLE_API_KEY, model="gemini-2.5-flash", temperature=1)

# Create a prompt
prompt = "How many states are there in India?"

# Pass the prompt to llm
print(llm.invoke(prompt))
# Out:
# content='There are **28 states** in India.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--e83d1ced-3f35-4ac0-b11d-ec0f276a922b-0' usage_metadata={'input_tokens': 9, 'output_tokens': 191, 'total_tokens': 200, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 181}}

# %%
# Import Google ChatModel
from langchain_google_genai import ChatGoogleGenerativeAI

# Set the OpenAI Key and initialize a ChatModel
chat_model = ChatGoogleGenerativeAI(google_api_key=GOOGLE_API_KEY, model="gemini-2.5-flash", temperature=1)

prompt = "Tell me a short joke about Data Science"

print(chat_model.invoke(prompt))
# Out:
# content="Why did the data scientist break up with the statistician?\n\nBecause he found a strong correlation between their arguments and his sleeping on the couch, but couldn't prove causation!" additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--6e46f797-4331-45ef-aa0c-fef97daf9010-0' usage_metadata={'input_tokens': 9, 'output_tokens': 2356, 'total_tokens': 2365, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 2320}}

# %% [markdown]
# ## **HuggingFace**

# %%
#!pip install langchain-huggingface

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
pipe = pipeline(
    task="text-generation", model=model, tokenizer=tokenizer, max_new_tokens=512
)

hf = HuggingFacePipeline(pipeline=pipe)

hf.invoke("What should I study to become a data scientist?")

# %%
from huggingface_hub import login
login() # You will be prompted for your HF key, which will then be saved locally

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

llm = HuggingFaceEndpoint(
    repo_id="microsoft/Phi-3-mini-4k-instruct",
    task="text-generation",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
)

chat = ChatHuggingFace(llm=llm, verbose=True)

# %%
chat.invoke("What is a curriculum to learn datascience")
