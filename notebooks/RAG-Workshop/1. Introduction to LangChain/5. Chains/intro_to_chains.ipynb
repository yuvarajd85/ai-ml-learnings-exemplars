# %% [markdown]
# # **Chains**
#
# Chains allows us to link the output of one LLM call as the input of another call.
#
# Chains refer to sequences of calls - whether to an LLM, a tool, or a data preprocessing step. The primary supported way to do this is with LCEL.

# %%
# Setup API Key

f = open('keys/.openai_api_key.txt')

OPENAI_API_KEY = f.read()

# %%
from langchain_openai import ChatOpenAI

# Set the OpenAI Key and initialize a ChatModel
chat_model = ChatOpenAI(openai_api_key=OPENAI_API_KEY)

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", """You are a helpful AI bot who expertise in Data Science Tutor. 
                      You are known to make any complex topic simpler even for a beginner."""),
        ("human", "What is {topic}?")
    ]
)

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = chat_template | chat_model | output_parser

# %% [markdown]
# ### **chain.invoke()**

# %%
user_input = {"topic": "Feature Selection"}

chain.invoke(user_input)
# Out:
# "Feature selection is the process of choosing a subset of relevant features (variables, predictors) for use in building machine learning models. The goal of feature selection is to improve the performance of the model by selecting the most important features and reducing the complexity of the model.\n\nFeature selection is important because:\n1. It helps in improving the model's accuracy by focusing on the most relevant features.\n2. It reduces overfitting by removing irrelevant or redundant features.\n3. It speeds up the training process by reducing the number of features the model needs to consider.\n\nThere are various techniques for feature selection, such as filter methods, wrapper methods, and embedded methods. Each technique has its own advantages and is suitable for different scenarios. It is essential to choose the right feature selection technique based on the dataset and the machine learning algorithm being used."

# %% [markdown]
# ### **chain.stream()**

# %%
for chunk in chain.stream(user_input):
    print(chunk, end="")
# Out:
# Feature selection is the process of choosing a subset of relevant features (variables, predictors) from the original set of features in a dataset. The goal of feature selection is to improve the performance of a machine learning model by selecting the most important features while removing irrelevant or redundant ones.
#
# Feature selection helps in reducing the dimensionality of the dataset, which can lead to faster training times, simpler models, and improved generalization performance. It also helps in avoiding overfitting and improving the model's interpretability.
#
# There are various techniques for feature selection, including filter methods, wrapper methods, and embedded methods, each with its own advantages and use cases. The choice of feature selection technique depends on the dataset, the machine learning algorithm being used, and the specific goals of the analysis.

# %% [markdown]
# ### **Legacy Chains**
#
# - **LLMChain (Legacy)**
# - **SimpleSequentialChain (Legacy)**
