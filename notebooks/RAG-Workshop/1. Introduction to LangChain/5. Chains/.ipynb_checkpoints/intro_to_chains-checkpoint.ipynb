# %% [markdown]
# # **Chains**
#
# Chains allows us to link the output of one LLM call as the input of another call.
#
# Chains refer to sequences of calls - whether to an LLM, a tool, or a data preprocessing step. The primary supported way to do this is with LCEL.

# %%
# Setup API Key

f = open('keys/.openai_api_key.txt')

OPENAI_API_KEY = f.read()

# %%
from langchain_openai import ChatOpenAI

# Set the OpenAI Key and initialize a ChatModel
chat_model = ChatOpenAI(openai_api_key=OPENAI_API_KEY)

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", """You are a helpful AI bot who expertise in Data Science Tutor. 
                      You are known to make any complex topic simpler even for a beginner."""),
        ("human", "What is {topic}?")
    ]
)

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = chat_template | chat_model | output_parser

# %% [markdown]
# ### **chain.invoke()**

# %%
user_input = {"topic": "Feature Selection"}

chain.invoke(user_input)
# Out:
# "Feature selection is the process of selecting a subset of relevant features (variables, predictors) for use in model construction. In simpler terms, it is about choosing the most important attributes that contribute the most to predicting the target variable while ignoring irrelevant or redundant features. \n\nFeature selection is important because it helps in:\n1. Improving the model's performance by reducing overfitting.\n2. Reducing the computational cost of training the model.\n3. Enhancing the interpretability of the model by focusing on the most important features.\n\nThere are various techniques for feature selection, such as filter methods, wrapper methods, and embedded methods. Each technique has its own advantages and is suitable for different scenarios based on the dataset and the model being used."

# %% [markdown]
# ### **chain.stream()**

# %%
for chunk in chain.stream(user_input):
    print(chunk, end="")
# Out:
# Feature selection is the process of choosing a subset of relevant features or variables from the original set of features in a dataset. The goal of feature selection is to improve the performance of a machine learning model by selecting the most important features and removing irrelevant or redundant ones.
#
# By selecting the most relevant features, we can simplify the model, reduce overfitting, improve accuracy, and reduce training time. Feature selection is an important step in the machine learning pipeline as it helps in creating more interpretable and efficient models.
#
# There are different techniques for feature selection such as filter methods, wrapper methods, and embedded methods. Each technique has its own advantages and is used based on the specific requirements of the problem at hand.

# %% [markdown]
# ### **Legacy Chains**
#
# - **LLMChain (Legacy)**
# - **SimpleSequentialChain (Legacy)**
