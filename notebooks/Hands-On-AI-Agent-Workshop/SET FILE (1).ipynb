# %% [markdown]
# # SETS

# %%
{1,2,3,10,20,4,5,6,7,8,2,3,4,5}
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 10, 20}

# %%
w=["stephen","hassan","sonali","nistha","rupal","stephen"]

# %%
set(w)
# Out:
# {'hassan', 'nistha', 'rupal', 'sonali', 'stephen'}

# %%
e={1,2,3,4,5,6,2,3,4,67}

# %%
e
# Out:
# {1, 2, 3, 4, 5, 6, 67}

# %%
x=[1,1,2,3,4,5,6,2,3,4,5,6,1,3,3,4,5,5,66,6, 123,23]
x

set(x)
# Out:
# {1, 2, 3, 4, 5, 6, 23, 66, 123}

# %% [markdown]
# # --------------------------ALTERNATIVE METHOD---------------------

# %%
x={1,1,2,3,4,5,6,2,3,4,5,6,1,3,3,4,5,5,66,6}
x
# Out:
# {1, 2, 3, 4, 5, 6, 66}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1801376b79be> in <module>
# ----> 1 x[0]="eerr"
#       2
#       3
#       4
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# # ---------------------SELF-DEFINED FUNCTIONS----------------------------------------

# %%
x
# Out:
# {1, 2, 3, 4, 5, 6, 66}

# %%
x.add("ebdhkfl")
x
# Out:
# {1, 2, 3, 4, 5, 6, 66, 'ebdhkfl', 'esh'}

# %%
x[1]=1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0be2e0a42bd2> in <module>
# ----> 1 x[1]=1000
#
# TypeError: 'set' object does not support item assignment

# %%
z={1,2,3,4,5,6,7,8,8,7,6,5,4,3,2,1,9,9,8,8,7,6,5,4,3,2,1}
z


type(z)
# Out:
# set

# %% [markdown]
# # -------------------------------INTERSECTION------------------------------

# %%
x
# Out:
# {1, 2, 3, 4, 5, 6, 66, 'ebdhkfl', 'esh'}

# %%
z
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
x.intersection(z)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # ----------------------------------------UNION--------------------------------------------------

# %%
x.union(z)
# Out:
# {1, 2, 3, 4, 5, 6, 66, 7, 8, 9, 'ebdhkfl', 'esh'}

# %% [markdown]
# # --------------------------------------------SUBSET------------------------------------------

# %%
y={1,2,3,4,5,6,"eshank"}
y
# Out:
# {1, 2, 3, 4, 5, 6, 'eshank'}

# %%
x
# Out:
# {1, 2, 3, 4, 5, 6, 66, 'ebdhkfl', 'esh'}

# %%
y.issubset(x)
# Out:
# False

# %%
z
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
y.issubset(z)
# Out:
# True

# %% [markdown]
# # -------------------------------------BITWISE OPERATOR IN SET THEORY-----------------

# %% [markdown]
# # ------------------------------------------ OR GATE--------------------------

# %%
x
z
x|z
# Out:
# {1, 2, 3, 4, 5, 6, 66, 7, 8, 9, 'ebdhkfl', 'esh'}

# %% [markdown]
# # ---------------------------------------------AND GATE-----------------------------------

# %%
y&z
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
x
# Out:
# {1, 2, 3, 4, 5, 6, 66, 'esh'}

# %%
z
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# # ---------------------------------XOR GATE---------------------------------

# %%
x
# Out:
# {1, 2, 3, 4, 5, 6, 66, 'ebdhkfl', 'esh'}

# %%
z
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
x^z
# Out:
# {66, 7, 8, 9, 'ebdhkfl', 'esh'}

# %%
{1,2,3,4,5,67}
# Out:
# {(1, 2, 3, 3, 4), 1, 2, 3, 4, 5, 67}
