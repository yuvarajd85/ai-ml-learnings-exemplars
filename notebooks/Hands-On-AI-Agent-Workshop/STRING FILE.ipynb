# %% [markdown]
# # ----------------------------STRINGS--------------------------------

# %%
s='hello world'
s
# Out:
# 'hello world'

# %%
s

type(s)
# Out:
# str

# %% [markdown]
# # ---------------------INDEXING--------------------------

# %%
s
# Out:
# 'hello world'

# %%
len(s)
# Out:
# 11

# %%
s[11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-d425bd771817> in <module>
# ----> 1 s[11]
#       2
#
# IndexError: string index out of range

# %% [markdown]
# # ---------------------------------SLICING-----------------------------
# #SYNTAX VARIABLENAME[STARTPOINT:ENDPOINT(N-1):JUMP OR DIRECTION]

# %% [markdown]
# # ------FORWARD SLICING-------------

# %%
s[1:7]
# Out:
# 'ello w'

# %%
s[0:8:2]
# Out:
# 'hlow'

# %% [markdown]
# # --------BACKWARD SLICING---------------

# %%
s
# Out:
# 'hello world'

# %%
s[5::-1]
# Out:
# ''

# %% [markdown]
# # --------------------------------Creating a String------------------

# %% [markdown]
# # -In Python, either single quote (‘) or double quotes (“) must be used while creating a string.

# %% [markdown]
# # Single word

# %%
a='hello'
a
# Out:
# 'hello'

# %% [markdown]
# # Entire phrase

# %%
 
b= 'This is also a string'
b
# Out:
# 'This is also a string'

# %% [markdown]
# # We can also use double quote

# %%
c="String built with double quotes"
c
# Out:
# 'String built with double quotes'

# %% [markdown]
# # Be careful with quotes!

# %%
d='I'm using single quotes, but will create an error'
d
# Out:
#   File "<ipython-input-24-240bd148005d>", line 1
#     d='I'm using single quotes, but will create an error'
#          ^
# SyntaxError: invalid syntax

# %%
e="Now I'm ready to use the single quotes inside a string!"
e
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %%
planet="jupiter"
radius=12800

# %%
print("the planet earth having radius is 6400km")
# Out:
# the planet earth having radius is 6400km

# %%
print("{}the planet {} having radius  is km".format(planet,radius))
# Out:
# jupiterthe planet 12800 having radius  is km

# %% [markdown]
# # ...........................string concatenate.....................
# # CONCATENATE MERELY WHEN BOTH ARE STRINGES

# %%
"stephen"+"hassan"+"nistha"
# Out:
# 'stephenhassannistha'

# %%
"stephen"+str(4)
# Out:
# 'stephen4'

# %%
s="ESHANK"+ str(4)
s

# %%
"ABHI"  +   "NIRB"

# %%
"eshank" + 4

# %% [markdown]
# # ----------built-in string handling method--------------------

# %%
s
# Out:
# 'hello'

# %%
s=" "

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.isdigit()
# Out:
# True

# %%
s.islower()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s="hello4"

# %%
s.endswith("5")
# Out:
# False

# %%
s.startswith("h")
# Out:
# True

# %%
my_st="SKILL65"
my_name="65"
print(my_st.isalpha() and my_name.isalnum())
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %% [markdown]
# # .........................string is not mutable(IMMUTABLE).....................

# %%
s
# Out:
# 'hello4'

# %%
s[0]="q"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-06419b691f30> in <module>
# ----> 1 s[0]="q"
#       2
#       3
#       4
#       5
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # ...............................strings in built functions.....................

# %%
s
# Out:
# 'hello4'

# %%
s.upper()
# Out:
# 'HELLO4'

# %%
s.lower()
# Out:
# 'hello4'

# %%
s.title()
# Out:
# 'Hello4'

# %% [markdown]
# # ...............................strip function......................

# %%
s="     hello$ world  "
s.strip()
# Out:
# 'hello$ world'

# %%
s.lstrip()
# Out:
# 'hello$ world  '

# %%
s.lstrip()

# %% [markdown]
# # ...............................split function......................................

# %%
s="helolo worold"

s.split()
# Out:
# ['helolo', 'worold']

# %%
s.split("o")
# Out:
# ['hel', 'l', ' w', 'r', 'ld']

# %%
s.split("o",maxsplit=1)
# Out:
# ['hel', 'lo worold']

# %%
s1="well#right#good"
s1.split("#")
# Out:
# ['well', 'right', 'good']

# %% [markdown]
# # .......................location and counting............................

# %%
s
# Out:
# 'helolo worold'

# %%
s.count("o")
# Out:
# 4

# %%
s.find("z")
# Out:
# -1

# %% [markdown]
# # ...................................Replace..........................

# %%
a="hello world"

# %%
a
# Out:
# 'hello world'

# %%
a.replace("h","q")
# Out:
# 'qello world'

# %%
a
# Out:
# 'hello world'

# %%
a=a.replace("h","q")

a
# Out:
# 'qello world'

# %% [markdown]
# # ....................................join.............................

# %%
a=""
b=["n","a","v","e","e","n"]

a=a.join(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-817b2aa22e93> in <module>
#       2 b=["n","a","v","e","e","n"]
#       3
# ----> 4 a=a.join(b)
#
# AttributeError: 'int' object has no attribute 'join'

# %%
a
# Out:
# 'naveen'
