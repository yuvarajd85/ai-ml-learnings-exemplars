# %%
Syntax:

enumerate(iterable, start=0)

Parameters:
Iterable: any object that supports iteration
Start: the index value from which the counter is to be started, by default it is 0 

__________________________________________________________EXAMPLES_______________________________________________________

# %%
l1 = ["DL","ML","NLP"] 
s1 = "PYTHON"

# %%
list(enumerate(s1))
# Out:
# [(0, 'P'), (1, 'Y'), (2, 'T'), (3, 'H'), (4, 'O'), (5, 'N')]

# %%
list(a)
# Out:
# [(10, 'DL'), (11, 'ML'), (12, 'NLP')]

# %%
list(b)
# Out:
# [(0, 'P'), (1, 'Y'), (2, 'T'), (3, 'H'), (4, 'O'), (5, 'N')]

# %%
b = enumerate(s1) 

list(a)
list(b)

list(enumerate(l1,100))

# %%
_______________________________________________________________with loops_________________________________________________
# Out:
#   File "<ipython-input-10-d508f1e0a52f>", line 1
#     _______________________________________________________________with loops_________________________________________________
#                                                                                                                              ^
# SyntaxError: invalid syntax

# %%
l2 = ["supervised","logistics","artifical"]

# %%
 
for i,j in zip(l2,range(len(l2))): 
    if j==1:
        print(i,j)
# Out:
# logistics 1

# %%
l1 = ["DL","ML","NLP"]

# %%
_____________________________________________________changing index and printing separately________________________________

# %%
for i,j in enumerate(l1):
    if i<2:
        print (j,i)
# Out:
# DL 0
# ML 1

# %%
blackshoe={38:4,39:6,40:0,41:5,42:8}
a=[]

# %%
while True:
    purchasesize=int(input("which shoe size would u like to buy : "))
    if purchasesize not in a :
        if blackshoe[purchasesize]>0:
            b=input("comment: ")
            if b in "intersted":
                 blackshoe[purchasesize]-=1
                 print(blackshoe)
                 break
            else:
                print("show different shoe")
                a.append(purchasesize)
        else:
            print("shoes are not longer in stock")
    else:
        print("already not interested")
# Out:
# which shoe size would u like to buy : 40
# shoes are not longer in stock
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-44aacd01043d> in <module>
#       1 while True:
# ----> 2     purchasesize=int(input("which shoe size would u like to buy : "))
#       3     if purchasesize not in a :
#       4         if blackshoe[purchasesize]>0:
#       5             b=input("comment: ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
