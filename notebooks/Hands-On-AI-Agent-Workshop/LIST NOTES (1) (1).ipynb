# %% [markdown]
# # -------------------------------BUILT- IN DATA STRUCTURE----------------------------
#
# ## LISTS
#
# ## STRINGS
#
# ##  SETS
#
# ## DICTIONARIES
#
# ## TUPLES

# %% [markdown]
# # ...................................Lists................................
#
# ## List is an ordered sequence of elements OR objects

# %%
q=[1,2,3,4.5,True,2+1j]
q
# Out:
# [1, 2, 3, 4.5, True, (2+1j)]

# %%
type(q)
# Out:
# list

# %%
names=["abdul","sonali","stephen","gracias","anjali"]

# %%
names
# Out:
# ['abdul', 'sonali', 'stephen', 'gracias', 'anjali']

# %%
names[0]
# Out:
# 'abdul'

# %%
names[2]
# Out:
# 'stephen'

# %%
names[4]
# Out:
# 'anjali'

# %%
a=1,2,3,4,5,6
a
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
type(a)
# Out:
# tuple

# %%
list((10,20))
# Out:
# [10, 20]

# %%
b=["eshank","sonali,gracias"]

# %%
type(b)
# Out:
# list

# %%
a= "eshank","sonali"

# %%
a
# Out:
# ('eshank', 'sonali')

# %%
list(a)
# Out:
# ['eshank', 'sonali']

# %%
list(a)
# Out:
# ['eshank', 'sonali']

# %%
b="eshank"

# %%
["eshank"]
# Out:
# ['eshank']

# %%
list(("eshank","stephen"))
# Out:
# ['eshank', 'stephen']

# %%
a=1,2,3,4,5,6,7

# %%
[1]
# Out:
# [1]

# %%
list(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7ade7017386b> in <module>
# ----> 1 list(1)
#
# TypeError: 'int' object is not iterable

# %%
list(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b="stephen"

# %%
list(b)
# Out:
# ['s', 't', 'e', 'p', 'h', 'e', 'n']

# %%
["stephen"]
# Out:
# ['stephen']

# %%
[]
# Out:
# ['sonali', 'stephen', 'edi', 'john']

# %%
a="sonali","stephen","edi","john"

# %%
a
# Out:
# ('sonali', 'stephen', 'edi', 'john')

# %%
list(a)
# Out:
# ['sonali', 'stephen', 'edi', 'john']

# %%
b="sonali","stephen","edi","john"
b
# Out:
# ('sonali', 'stephen', 'edi', 'john')

# %%
list(b)
# Out:
# ['sonali', 'stephen', 'edi', 'john']

# %%
# .........................INDEXING............................

## two types of indexing 

# a) forward indexing ( 0,1,2,3,4,5,6,7,8)

# b) backward indexing( -1,-2,-3,-4,-5,-6)

# %% [markdown]
# # forward indexing ( 0,1,2,3,4,5,6,7,8)

# %%
l=["skill",23,45,23,98,1000,765,1,2,3,4,5,6,7,8,910,'a',"nish"]


l
# Out:
# ['skill', 23, 45, 23, 98, 1000, 765, 1, 2, 3, 4, 5, 6, 7, 8, 910, 'a', 'nish']

# %%
len(l)
# Out:
# 18

# %%
l[18]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 l[18]
#
# IndexError: list index out of range

# %%
l[10]
# Out:
# 4

# %%
len(l)
# Out:
# 18

# %%
l[17]
# Out:
# 'nish'

# %%
l[18]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l[18]
#
# IndexError: list index out of range

# %%
l[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l[20]
#
# IndexError: list index out of range

# %% [markdown]
# # ..................................  SLICING........................
#
# # SYNTAX-- l[startpoint(index_value) : endpoint(n-1) : jump or direction]

# %%
l
# Out:
# ['skill', 23, 45, 23, 98, 1000, 765, 1, 2, 3, 4, 5, 6, 7, 8, 910, 'a', 'nish']

# %%
l[1:9:2]
# Out:
# [23, 23, 1000, 1]

# %% [markdown]
# ###

# %% [markdown]
# # --------------------------------JUMP---------------------------------
#
# #--------+ve direction jump------------------------------------------

# %%
l
# Out:
# ['skill', 23, 45, 23, 98, 1000, 765, 1, 2, 3, 4, 5, 6, 7, 8, 910, 'a', 'nish']

# %% [markdown]
# # -------------------------------------BACKWARD SLICING----------------
#
# #SYNTAX [ STARTPOINT : END POINT : JUMP OR DIRECTION]

# %%
q=["v","m","g","a","e","k"]

q
# Out:
# ['v', 'm', 'g', 'a', 'e', 'k']

# %%
q[0]
# Out:
# 'v'

# %%
q[-6]
# Out:
# 'v'

# %%
q=["v","m","g","a","e","k"]

q[::-1]
# Out:
# ['k', 'e', 'a', 'g', 'm', 'v']

# %%
l
# Out:
# ['skill', 23, 45, 23, 98, 1000, 765, 1, 2, 3, 4, 5, 6, 7, 8, 910, 'a', 'nish']

# %%
l[-1:-5:-1]
# Out:
# ['nish', 'a', 910, 8]

# %%
l[2:9:-1]
# Out:
# []

# %% [markdown]
# # --------------------------------NESTED LIST-------------------------

# %%
l=["n","a","m",[1,2,3],"abhi","nitin"]

l
# Out:
# ['n', 'a', 'm', [1, 2, 3], 'abhi', 'nitin']

# %%
l[3][1]
# Out:
# 2

# %% [markdown]
# # _____________________________MUTABILITY___________________________

# %%
l
# Out:
# ['n', 'a', 'm', [1, 2, 3], 'abhi', 'nitin']

# %%
l[3]="hasan"
l
# Out:
# ['n', 'a', 'm', 'hasan', 'abhi', 'nitin']

# %% [markdown]
# # -------------------SELF-DEFINED FUNCTIONS FOR LIST------------

# %% [markdown]
# # -----------------------append function---------------------

# %%
q
# Out:
# [1, 2, 3, 4.5, True, (2+1j)]

# %%
q.append([10,20,30])
q
# Out:
# [1, 2, 3, 4.5, True, (2+1j), [10, 20, 30]]

# %%
a=["anjali","stephen","vijay","gracias"]

# %%
q.append(["anjali","stephen","vijay","gracias"])
q
# Out:
# ['v',
#  'm',
#  'g',
#  'a',
#  'e',
#  'k',
#  'eshank',
#  10,
#  ['anjali', 'stephen', 'vijay', 'gracias']]

# %%
q.append()
q
# Out:
# ['v', 'm', 'g', 'a', 'e', 'k', 'hasan', ['hasan', 'stephen']]

# %% [markdown]
# # #.............................extend fuction( to add a list).....................

# %%
q
# Out:
# [1, 2, 3, 4.5, True, (2+1j), [10, 20, 30]]

# %%
q.extend(["hasan","stephen"])


q
# Out:
# [1, 2, 3, 4.5, True, (2+1j), [10, 20, 30], 'hasan', 'stephen']

# %%
q.extend("ritesh")
q
# Out:
# [1,
#  2,
#  3,
#  4.5,
#  True,
#  (2+1j),
#  [10, 20, 30],
#  'hasan',
#  'stephen',
#  'r',
#  'i',
#  't',
#  'e',
#  's',
#  'h']

# %% [markdown]
# # -----------------------------------------REMOVE---------
# #syntax: l.remove(object)

# %%
l
# Out:
# ['n', 'a', 'm', 'hasan', 'abhi', 'nitin']

# %%
l.remove("hasan")

# %%
l
# Out:
# ['n', 'a', 'm', 'abhi', 'nitin']

# %% [markdown]
# # ....................................insert................................
# # SYNTAX:-  variable.insert (index,datatype)

# %%
l
# Out:
# ['n', 'a', 'm', 'abhi', 'nitin']

# %%
l[1]="leena"

# %%
l
# Out:
# ['n', 'leena', 'a', 'taimi', 'm', 'abhi', 'nitin']

# %%
l
l.insert(3,"taimi")
l
# Out:
# ['n', 'raza', 'a', 'taimi', 'm', 'abhi', 'nitin']

# %% [markdown]
# # -------------------------------SUBSITITUTION(MUTABLE)--------------------

# %%
l
# Out:
# ['n', 'raza', 'a', 'm', 'abhi', 'nitin']

# %%
l[3]=1
l
# Out:
# ['n', 'raza', 'a', 1, 'abhi', 'nitin']

# %% [markdown]
# # ...........................reverse.........................

# %%
l
# Out:
# ['n', 'leena', 'a', 'taimi', 'm', 'abhi', 'nitin']

# %%
l.reverse()
l
# Out:
# ['nitin', 'abhi', 'm', 'taimi', 'a', 'leena', 'n']

# %%
l[::-1]
# Out:
# ['n', 'leena', 'a', 'taimi', 'm', 'abhi', 'nitin']

# %% [markdown]
# # ............................sort.......................

# %%
l=[2,1,6,78,32,14,23,78,98,0,54,14,39,45,2,9,2,3,2]
l.sort()
l
# Out:
# [0, 1, 2, 2, 2, 2, 3, 6, 9, 14, 14, 23, 32, 39, 45, 54, 78, 78, 98]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [98, 78, 78, 54, 45, 39, 32, 23, 14, 14, 9, 6, 3, 2, 2, 2, 2, 1, 0]

# %%
l=["a","g","es",23,56,100,"c","esh","w","o","es",10,20,30,"pr","es"]
l.sort()
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-1764b0d612ab> in <module>
#       1 l=["a","g","es",23,56,100,"c","esh","w","o","es",10,20,30,"pr","es"]
# ----> 2 l.sort()
#       3 l
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
a=5.1,5.2,5.3

# %%
l=[2,1,6,78,32,14,23,78,98,0,54,14,39,45,2,9,2,3,2]
l.sort(reverse=True)
l
# Out:
# [98, 78, 78, 54, 45, 39, 32, 23, 14, 14, 9, 6, 3, 2, 2, 2, 2, 1, 0]

# %%
l=["a","c","c","w","h"]
l.sort(reverse=True)
l
# Out:
# ['w', 'h', 'c', 'c', 'a']

# %% [markdown]
# # .............................pop...............................
# # syntax variable.pop(index)

# %%
l
# Out:
# ['a',
#  'es',
#  'g',
#  23,
#  56,
#  100,
#  'c',
#  'esh',
#  'w',
#  'o',
#  'es',
#  10,
#  20,
#  30,
#  'pr',
#  'es']

# %%
l
# Out:
# ['a',
#  'es',
#  'g',
#  23,
#  56,
#  100,
#  'c',
#  'esh',
#  'w',
#  'o',
#  'es',
#  10,
#  20,
#  30,
#  'pr',
#  'es']

# %%
l
# Out:
# ['a', 'g', 23, 56, 100, 'c', 'esh', 'w', 'o', 'es', 10, 20, 30, 'pr', 'es']

# %%
l.pop(1)
# Out:
# 'es'

# %% [markdown]
# # .............................count.........................
# # syntax l.count(object)

# %%
l
# Out:
# ['a', 'g', 23, 56, 100, 'c', 'esh', 'w', 'o', 'es', 10, 20, 30, 'pr', 'es']

# %%
l.count("es")
# Out:
# 2

# %% [markdown]
# # ...............................length...............................
# #syntax len(varaible name)

# %%
len(l)
# Out:
# 4

# %% [markdown]
# # ................................index.................................
# #syntax l.index( object name)

# %%
l=[2,1,6,78,32,14,23,78,98,0,54,14,39,45,2,9,14,78,2,3,2]

# %%
l.index(78,8)
# Out:
# 17

# %%
def index_func(a,b):
    r=[]
    for i ,j in zip(a,range(len(a))):
        if i==b:
            r.append(j)
    return r

# %%
index_func(l,78)
# Out:
# [3, 7, 17]

# %%
l
# Out:
# [2, 1, 6, 78, 32, 14, 23, 78, 98, 0, 54, 14, 39, 45, 2, 9, 14, 78, 2, 3, 2]

# %%
l.index(14)
# Out:
# 5

# %%
l[5]="eshank"

# %%
l
# Out:
# [2,
#  1,
#  6,
#  78,
#  32,
#  'eshank',
#  23,
#  78,
#  98,
#  0,
#  54,
#  14,
#  39,
#  45,
#  2,
#  9,
#  14,
#  78,
#  2,
#  3,
#  2]
