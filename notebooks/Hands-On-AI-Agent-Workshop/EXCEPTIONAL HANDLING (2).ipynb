# %%
try:
    a=int(input("enter your number"))
    b=int(input("enter your number"))
    c=a/b
   
except Exception as e:
    print(e)

else:
    print(c)
finally:
    print("hello everyone")
# Out:
# enter your number10
# enter your number2
# 5.0
# hello everyone

# %%
______________________________________________________________TYPES OF ERROR___________________________________________________________

1- COMPILE ERROR
2- LOGICAL ERROR
3- RUNTIME ERROR

# %%
_______________________________________________________________________________________________________________________________________

COMPILE ERROR

like:- SYNTAX ERROR

(if you missed to put : in if condition or wrong spelling of print())

# %%
______________________________________________________________________________________________________________________________________

LOGICAL ERROR

like :- wrong output

# %%
______________________________________________________________________________________________________________________________________

RUNTIME ERROR

( EXCEPTION HANDLING)

# %%
for i in range(5):
    
    try:
        a=int(input("enter your number"))
        b=int(input("enter your number"))
        print(a/b)


    except:
        print("greater than zero")
        continue

# %%
________________________________________________________________EXCEPTION HANDLING__________________________________________________


a=5
b=0

try:
    print(a/b)
except Exception as e:
    print(e)

print("bye")

# %%
a=5
b=0

try:
    print(a/b)
    
except TypeError :
    print("type different values of b")
except ZeroDivisionError :
    print("greater than zero")
except Exception as e :
    print(e)

print("bye")
# Out:
# greater than zero
# bye

# %%
a=5
b=0

a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-5a044ba2c6d9> in <module>
#       2 b=0
#       3
# ----> 4 a/b
#
# ZeroDivisionError: division by zero

# %%
a=5
b="12"

try:
    
    print("resource open")
    print(a/b)
    print("resource closed 123")

except Exception as e :
    print(e)

print("resource closed")
# Out:
# resource open
# unsupported operand type(s) for /: 'int' and 'str'
# resource closed

# %%
a=5
b=0

try:
    
    print("resource open")
    print(a/b)
    

except Exception as e :
    print("zero cannot be used to divide any number :",e)
    print("resource closed")

# %%
    
a=5
b=10

try:
    
    print("resource open")
    print(a/b)
    

except Exception as e :
    print("zero cannot be used to divide any number :",e)
    

else:
     print("resource closed")
# Out:
# resource open
# 0.5
# resource closed

# %%
a=5
b="a"

try:
    print(a/b)
    c=int(input("type your number"))
    print(c)

except ZeroDivisionError as e:
    print("zero cannot be used to divide any number :",e)


except TypeError as e:
    print( "invalid input : ",e)
    
except Exception as e:
    print("something is fishy",e)
    

finally:
    print("resource closed")

# %%
for i in range(3):
    a=int(input("enter your number"))
    b=int(input("enter your number"))
    try:
        print(a/b)
    except:
        print("define your no . greater than zero")
        continue
# Out:
# enter your number10
# enter your numbera
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4a9837dbcd34> in <module>
#       1 for i in range(3):
#       2     a=int(input("enter your number"))
# ----> 3     b=int(input("enter your number"))
#       4     try:
#       5         print(a/b)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
a=[1,2,3,2,"5",7,2,39,3]

# %%
b=0
for i in a:
    try:
        if i>b :
            b=i
    except Exception as e:
        print(e)
        continue
# Out:
# '>' not supported between instances of 'str' and 'int'

# %%
a=["a1","b2","c3","d4","e5","f6","gg","w8"]

# %%
w=[]
for i in a:
    try:
        if type(int(i[1]))==int:
            w.append(int(i[1]))
    except Exception as e:
        print(e)
# Out:
# invalid literal for int() with base 10: 'g'

# %%
w
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
type(1)
# Out:
# int
