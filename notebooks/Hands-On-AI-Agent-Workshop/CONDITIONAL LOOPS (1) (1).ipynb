# %% [markdown]
# # -----------------------------conditional loops--------------------------

# %%
if 15<10:
    print("my no is less than 5")
else:
    print("greater than 10")
# Out:
# greater than 10

# %%
a=233434

# %%
if a%2==0:
    print("no is even")
else:
    print("no is not even")
# Out:
# no is even

# %%
if a%5==0:
    print("hello")


else:
    print("bye bye")
# Out:
# bye bye

# %%
suraj=10

if suraj%2==0:
    print("my no is even",suraj)
else:
    print("my no. is not even")
# Out:
# my no is even 10

# %%
x=27

if x%3==0:
    print("my no. {} is divisible by 3".format(x))
else:
    print(x,"not divisible")
# Out:
# my no. 27 is divisible by 3

# %%
x=204
if x%2==0:
    print(  "my no. {} is even".format(x))
else:
    print("no is odd")
# Out:
# my no. 204 is even

# %%
a="anup"

b="deep learning"

print("name is {} and teaching {}".format(a,b))
# Out:
# name is anup and teaching deep learning

# %%
x=300

if x>=220:
    print(" my no. {} is greater than 220".format(x))
elif 200<=x<=220:
    print ("my no. {} lies b/w 200 & 220".format(x))
elif 150<=x<=199:
    print("{} lies b/w 150 & 199".format(x))
elif 120<=x<=149:
    print("hello")
else:
    print("my no. is less than 150")
# Out:
#  my no. 300 is greater than 220

# %%
a
# Out:
# 3

# %%
like=0
dislike=0

# %%
like+=1

# %%
click="dislike"

# %%
if click=="like":
    like=like+1
    print(like,"like")
else:
    dislike+=1
    print(dislike,"dislike")
# Out:
# 1 dislike

# %%
a="hasssan"

# %%
print("my name is {}".format(a))
# Out:
# my name is hasssan

# %%
time="night"
sleepy=False
watching="comedy show"

# %%
if time=="night" and sleepy==True or watching=="movie":
    print (" wear lower")
else:
    print("not lower")
# Out:
# not lower

# %% [markdown]
# # -----------------------NESTED CONDITIONAL LOOPS-----------------

# %%
i=100

if i==100:
    print(i*2)
    print(2+2)
    print(i/5)
# Out:
# 200
# 4
# 20.0

# %%
i=20

if i==20:
    print("welcome")
    print("good one")
    if i>15:
        print("less than")
    elif 5<i<10:
        print("lies b/w 5 & 10")
    else:
        print("no sense")
else:
    print("bye bye")
# Out:
# welcome
# good one
# less than

# %%
i=95

if i>10 and i<89:
    print("welcome",end="#")
    print("hello",end="@")
    print("byebye",end="\n")
    if i==10:
        print("bye")
    elif 20<i<100:
        print("got it")
    elif i==20 or i<20:
        print("too complicated")
    else:
        print("done")
    
elif i<23 and i>90:
    print(3*i)
    
    if i>50:
        print()
    elif 10<i<75:
        print(2*i)
    elif i==10:
            print(3*i)
    else:
        print("none")
        

else:
    print("good")
# Out:
# good

# %%
i=20
j=25

if i==20 or j<23:
    print(i)
    if j>25:
        print(2*j)
    elif 20<=j<26:
        print(3*j)
    elif 24<=j<=25:
        print(6*j)
    else:
        print(4*j)
elif 20<=i<89:
    print("bye bye we will do rest of the part in the next class")
    
    
else:
    print("none")
# Out:
# 20
# 69

# %%
time="5:00pm"

# %% [markdown]
# if int(time[0])<1:
#     print("its afternoon")
# elif int(time[0])>1 :
#     print("its evening")
# else:
#     print("no sense")

# %%
print("teju",end="@")
print("hello")
# Out:
# teju@hello
