# %% [markdown]
# # ----------------------DATA TYPE OR PRIMITIVE DATA STRUCTURE---------------
#
# # a)BOOLEAN
#
# # b)FLOAT
#
# # c)INT
#
# # d)STRING
#
# # e)COMPLEX

# %%
x=False

type(x)
# Out:
# bool

# %%
x=4.5
type(x)
# Out:
# float

# %%
x=6

type(x)
# Out:
# int

# %%
x="abhi"
x='abhi'
type(x)
# Out:
# str

# %%
y=2+1j
y

type(y)
# Out:
# complex
