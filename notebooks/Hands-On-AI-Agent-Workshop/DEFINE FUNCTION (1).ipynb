# %% [markdown]
# # ................................DEFINING THE FUNCTIONS..........................

# %%
def eshank(a,b,c):
    return(a+b+c)

# %%
w=eshank(10,20,30)

# %%
w
# Out:
# 60

# %%
eshank(1,2222323,424366043)
# Out:
# 426588367

# %%
def sums(r,t,u):
    return(r+t+u)


naveen=sums(10,20,30)

naveen


naveen
# Out:
# 60

# %%
def sums(a,b,c,d,e):
    return(a*2,b*6)

# %%
sums(2,3,4,5,8)
# Out:
# (4, 18)

# %%
def add(a,b):
    return(a+b)

add(10,7765)
# Out:
# 7775

# %%
def hello(name,gender):
    return("my name is {} and gender is {}".format(name,gender))

hello("jyoti","female")
# Out:
# 'my name is jyoti and gender is female'

# %%
def hello(name,age=29,gender="male"):
    return("my name is {} and age is {} and gender is {}".format(name,age,gender))

# %%
hello("hassan",34,"male")
# Out:
# 'my name is hassan and age is 34 and gender is male'

# %%
#-----------------------------------------   ORDERING -------------------------------------
# you have to bear in mind that order counts. 
# Just as non-default arguments have to precede default arguments, so *args must come before **kwargs
# To recap, the correct order for your parameters is:

# %%
1-Standard arguments
2-args arguments( positional argument)
3-Default argument
3-kwargs arguments ( keyword argument)
4-*args
5-**kwargs

# %%
#--------------------------------------------EXAMPLE----------------------------------------
def my_function(a,b, c=1000, *args, **kwargs):
    pass

# %%
def my_function(a, b=100,c):
    pass
# Out:
#   File "<ipython-input-43-441a8bf4c0f6>", line 1
#     def my_function(a, b=100,c):
#                    ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# # #...............................FORMAT OF args,kwargs ............................................
#
# 1)unpacking operators are operators that unpack the values from iterable objects in Python.
#
# 2)The single asterisk operator * can be used on any iterable that Python provides,
#
# 3)while the double asterisk operator ** can only be used on dictionaries.

# %%
u = [1, 2, 3]
print(*u)
# Out:
# 1 2 3

# %%
a,*b,c=[1,2,3,4,5,6,7]
a
b
c

# %%
#-----------MEANING OF *args( POSITIONAL ARGUMENT :- to unpack iterables)----------



A=[1,2,3]
B=[4,5,6]
C=[A,B]
C
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
D=[*A,*B]    
D

# %%
a=[*"realpython"]
a

# %%
#----------------------MEANING OF **kwargs (KEYWORD ARGUMENT:- to unpack dictionaries)-------------------------
d1= {"A": 1, "B": 2}
d2 = {"C": 3, "D": 4}
d3= {**d1, **d2}    
d3



d4={d1,d2}

# %% [markdown]
# we can also use this method to call our own functions, but if our function requires a specific number of arguments,
# then the iterable we unpack must have the same number of arguments.

# %%
def my_sum(a,b,c,d,e):
    return(a+b+c+d+e)

mylist = [1, 2, 3,6,7]



my_sum(*mylist)

# %%
d=[1,2,3,4,5,6,7,8,9]

def my_sum(*a):
    result = 0
    for i in a:
        result += i
    return result


my_sum(*d)
# Out:
# 45

# %%
list1 = [1, 2, 3]
list2 = [4, 5]
list3 = [6, 7, 8, 9]

my_sum(*list1,*list2,*list3)
# Out:
# 45

# %%
#................................................  PRINT VS RETURN  ...........................................

# print function doesnot return any value but RETURN function will rreturn the value.
# RETURN function does not run iteratively, but print does
num=[1,2,3,4,5,6]

for i in num:
    if i%2==0:
        print(i)

# %%
b=[]

def even(a):
    for i in a:
        if i%2==0:
            b.append(i)
    return(b)
            
l=[1,2,3,4,5,6,7]

even(l)

# %%
#----------------------------------------------EXAMPLES-------------------------------------------------------------
w=[]
o=[]
def even_odd(num):
    for i in num:
        if i%2==0:
          w.append(i)
        else:
            o.append(i)
    return(w,o)
        
l=[1,2,3,4,5,6,7]          
even_odd(l)

q








....................................................................................................


def even_sum(num):
    sum=0
    q=[]
    
    for i in num:
        if i%2==0:
            sum+=i
            q.append(i)
    
    return(q,sum)
   

l=[1,2,3,4,5,6]          
arpit=even_sum(l)
arpit

q


#....................................EXAMPLE BY PRINT........................................

lst=[1,2,3,4,5,6,9,12,31,34,51,56]
def sumevenodd(lst):
    even_sum=0
    odd_sum=0
    for i in lst:
        if i%2==0:
            even_sum=even_sum+i
            print(i,"=","EVEN",":","CUMSUM",even_sum)
        else:
            odd_sum=odd_sum+i
            print(i,"=","ODD",":","CUMSUM",odd_sum)
   
a=sumevenodd(lst)
a

#......................................EXAMPLE BY RETURN..........................................
 
def even_odd_sum(num):
    even=[]
    odd=[]
    even_sum=0
    odd_sum=0
    for i in num:
        if i%2==0:
            even.append(i)
            even_sum=even_sum+i
        else:
            odd.append(i)
            odd_sum=odd_sum+i
    return(even,even_sum,odd,odd_sum)
 

ert=even_odd_sum(lst)

ert
#......................................................................................................................#


l=[1,2,3,4]
def square (num):
    a=[]
    m=0
    for b in num:
        x=b**2
        a.append(x)
       
        for i in a:
            m=m+i    
    return(m)

square(l)

#----------------------------------------------------------------------------------------------------------------------#

# %%
def prime(num):
    for i in range(2,num):
        if num % i== 0:
            print("not prime")
            break
    else:
        print("prime")


prime(9999887)



def prime (a,b):
    result=[]
    for i in range(a,b):
        if i>1:
            for j in range(2,i):
                if i%j==0:
                    break
            else:
                result.append(i)
    return(result)

a=prime(5,23)
a
a
#---------------------------------------------------------------------------------------------------------------------#




l=[1,2,4,5,2,5,6,7,8,7,5]


l.index(5)



def fun(a,b):
   c=[]
   for i in range(len(a)):
       if l[i]==b:
          c.append(i)
   return(c)



fun(l,5)


a=[1,2,3,4,5,6,2,3,5]
